# %%
class Company:
  def __init__(self, name, lname, age, langs):
    self.first_name=name
    self.last_name=lname
    self.age=age
    self.language=langs
    self.a={"Name":name, "Last Name":lname, "Age":age, "Languages":langs}
  def print_info(self):
    print(self.first_name +" "+self.last_name +" is " +self.level +". He/She knows " +self.language)
class Employeers(Company):
  level="employeer"
  

class Managers(Company):
  level="manager"

emp1 = Employeers("John", "Franklin", "28", "English and German")
emp2 = Employeers("Jerry", "Dyer", "25", "English and French")
emo3 = Employeers ("Mert", "Cekuc", "23", "English and Turkish")

man1= Managers ("Ahmet", "Kilic", "54", "English, Japanese and Turkish")
man2= Managers ("Oscar", "Pena", "48", "English, Arabic and Italian")



man1.print_info()
# Out:
# Ahmet Kilic is manager. He/She knows English, Japanese and Turkish
